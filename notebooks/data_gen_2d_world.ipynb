# %%
import numpy as np 
from belief_dynamics_learning.world2d import World2D

# %load_ext autoreload
# %autoreload 2

# %%
num_particles = 100
dt=0.1

# object properties 
dim_object = np.array([0.067, 0.14])
qo_gt = np.array([0, 1, 0]) # ground truth object pose
sigma_pos = 0.06 # standard deviation of position noise

# robot properties
qr_0 = np.array([0, 0.7])
r_robot = 0.05

# %%
world = World2D(num_particles, qo_gt, dim_object, sigma_pos, 
                qr_0, r_robot, dt)
world.plot_belief()
# Out:
# 0

# %%
q_r_hist, o_hist, u_hist = world.rollout(100, world.qo_gt)
print(q_r_hist.shape, o_hist.shape)
world.plot_rollout(q_r_hist, o_hist)
# Out:
# (101, 2) (101,)
